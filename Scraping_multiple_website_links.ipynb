# %% [markdown]
# <a href="https://colab.research.google.com/github/zeroyip175/python_swc/blob/main/Scraping_multiple_website_links.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import re

def add_protocol_to_domain(domain, is_https=True):
    protocol = "https://" if is_https else "http://"
    url = protocol + domain
    return url

# Read multiple website links from the file E.g. /content/sample_data/wesites.txt
with open('/content/sample_data/wesites.txt','r') as file:
  websites = [line.strip() for line in file.readlines()]

for domain in websites:
    try:
        use_https = True
        path = 'contact/'
        extra_path = '-us'
        url = add_protocol_to_domain(domain, is_https=use_https)   #+ path + extra_path # Replace with the URL of the website you want to scrape

        # Send HTTP GET request
        response = requests.get(url)
        website_content = response.text

        def find_social_media_links(website_content):
            # Regular expressions for Facebook, Instagram, Twitter, and YouTube URLs
            pattern_facebook = r'(?:https?:\/\/)?(?:www\.)?facebook\.com\/\S+'
            pattern_instagram = r'(?:https?:\/\/)?(?:www\.)?instagram\.com\/\S+'
            pattern_twitter = r'(?:https?:\/\/)?(?:www\.)?twitter\.com\/\S+'
            pattern_youtube = r'(?:https?:\/\/)?(?:www\.)?youtube\.com\/\S+'
            pattern_linkedin = r'(?:https?:\/\/)?(?:www\.)?linkedin\.com\/\S+'

            # Find all matches using regular expressions
            matches_facebook = re.findall(pattern_facebook, website_content, re.IGNORECASE)
            matches_instagram = re.findall(pattern_instagram, website_content, re.IGNORECASE)
            matches_twitter = re.findall(pattern_twitter, website_content, re.IGNORECASE)
            matches_youtube = re.findall(pattern_youtube, website_content, re.IGNORECASE)
            matches_linkedin = re.findall(pattern_linkedin, website_content, re.IGNORECASE)

            # Return the detected social media links
            social_media_links = {
                "Facebook": matches_facebook,
                "Instagram": matches_instagram,
                "Twitter": matches_twitter,
                "LinkedIn": matches_linkedin,
                "YouTube": matches_youtube

            }

            return social_media_links

        # Call the find_social_media_links function
        social_media_links = find_social_media_links(website_content)

        # Check if the request was successful
        if response.status_code == 200:
            # Parse the HTML content
            soup = BeautifulSoup(response.content, 'html.parser')

            # Search for contact information using regex patterns
            contact_info = soup.get_text()  # Get all text content from the page
            email_pattern = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'  # Regex pattern for email addresses
            phone_pattern = r'\b(?:\+?(\d{1,3}))?[-. (]?(\d{3})[-. )]?(\d{3})[-. ]?(\d{4})\b'  # Regex pattern for phone numbers
            telegram_pattern = r'\b(?:\+\d{1,3}[-. ])?\(?[0-9]{2}\)?[-. ]?(?:[0-9]{2}[-. ]?){2}[0-9]{2}\b'  # Regex pattern for telegram
            whatsapp_pattern = r'\b(?:\+\d{1,3}[-. ]?)?[1-9]\d{0,2}[-. ]?\d{2,3}[-. ]?\d{4}\b'# Regex pattern for whatsapp

            # Extract email addresses using the email pattern
            emails = re.findall(email_pattern, contact_info)

            # Extract phone numbers using the phone pattern
            phone_numbers = re.findall(phone_pattern, contact_info)

            # Extract phone numbers using the phone pattern
            telegram_no = re.findall(telegram_pattern, contact_info)

            # Extract phone numbers using the phone pattern
            whatsapp_no = re.findall(whatsapp_pattern, contact_info)

            # Print the detected social media links
            for platform, links in social_media_links.items():
                if links:
                    print(f"{platform} links found for {domain}:")
                    for link in links:
                        print(link)

            # Search for contact form
            form_tags = soup.find_all('form')
            for form in form_tags:
                if 'contact' in str(form).lower():
                    print("Found HTML contact form for " + domain)
                    break
            else:
                print("No HTML contact form found for " + domain)

            # Print the extracted contact information
            if emails:
                print('Email addresses for ' + domain + ':')
                for email in emails:
                    print(email)
            else:
                print('No email addresses found for ' + domain)

            if phone_numbers:
                print('Phone numbers for ' + domain + ':')
                for phone in phone_numbers:
                    print(phone)
            else:
                print('No phone numbers found for ' + domain)

            if telegram_no:
                print('Telegram for ' + domain + ':')
                for telegram in telegram_no:
                    print(telegram)
            else:
                print('No telegram found for ' + domain)

            if whatsapp_no:
                print('Whatsapp for ' + domain + ':')
                for whatsapp in whatsapp_no:
                    print(whatsapp)
            else:
                print('No whatsapp found for ' + domain)
                print('')
                print('============================================')

        else:
            print('Failed to retrieve website content for ' + domain)
            print('Status code: ' + str(response.status_code))
            print('============================================')

    except requests.exceptions.RequestException as e:
        print('')
        print('An error occurred while accessing ' + domain + ': ' + str(e))
        print('')
        print('============================================')
# Out:
# An error occurred while accessing best-rich.info: HTTPSConnectionPool(host='best-rich.info', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0197063160>: Failed to resolve 'best-rich.info' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing xsrv.jp: HTTPSConnectionPool(host='xsrv.jp', port=443): Max retries exceeded with url: / (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7c01970623e0>, 'Connection to xsrv.jp timed out. (connect timeout=None)'))
#
# ============================================
# Twitter links found for fx-navi-net.com:
# twitter.com/gawy512g"
# No HTML contact form found for fx-navi-net.com
# No email addresses found for fx-navi-net.com
# No phone numbers found for fx-navi-net.com
# No telegram found for fx-navi-net.com
# No whatsapp found for fx-navi-net.com
#
# ============================================
# No HTML contact form found for まどカスの技術メモ.com
# No email addresses found for まどカスの技術メモ.com
# No phone numbers found for まどカスの技術メモ.com
# No telegram found for まどカスの技術メモ.com
# No whatsapp found for まどカスの技術メモ.com
#
# ============================================
# Facebook links found for secinet.info:
# https://www.facebook.com/share.php?u=https%3A%2F%2Fwww.secinet.info"
# Twitter links found for secinet.info:
# https://twitter.com/yousuke4067/status/1218515748110290945?ref_src=twsrc%5Etfw">January
# https://twitter.com/gcdr06e6/status/1008587993886572545?ref_src=twsrc%5Etfw">June
# https://twitter.com/hashtag/%E3%83%90%E3%82%A4%E3%83%8A%E3%83%AA%E3%83%BC%E3%82%AA%E3%83%97%E3%82%B7%E3%83%A7%E3%83%B3?src=hash&amp;ref_src=twsrc%5Etfw">#バイナリーオプション</a>
# https://twitter.com/hashtag/%E3%83%90%E3%82%A4%E3%83%8A%E3%83%AA%E3%83%BC%E3%82%AA%E3%83%97%E3%82%B7%E3%83%A7%E3%83%B3%E5%85%83%E9%81%8B%E5%96%B6?src=hash&amp;ref_src=twsrc%5Etfw">#バイナリーオプション元運営</a></p><p>—
# https://twitter.com/Rzno5wtGleKEA7u/status/1159760108227719173?ref_src=twsrc%5Etfw">August
# https://twitter.com/bakuosan/status/1197462366977327104?ref_src=twsrc%5Etfw">November
# https://twitter.com/cows_botan/status/714314136314744832?ref_src=twsrc%5Etfw">March
# https://twitter.com/binary35over/status/1110375801269022721?ref_src=twsrc%5Etfw">March
# https://twitter.com/hashtag/%E3%83%9B%E3%83%AB%E3%83%A2%E3%83%B3%E8%A3%9C%E5%AE%8C%E8%A8%88%E7%94%BB?src=hash&amp;ref_src=twsrc%5Etfw">#ホルモン補完計画</a>‼️</p><p>海外バイナリーで出金設定に不備があった為、出金に手間がかかってしまった💦</p><p>本日ようやく出金‼️<br>手数料が少々💦</p><p>5,106円‼️</p><p>さて…</p><p>—
# https://twitter.com/Major_hormone/status/1119139263113678849?ref_src=twsrc%5Etfw">April
# https://twitter.com/jyonun_trx/status/1098250751933968384?ref_src=twsrc%5Etfw">February
# https://twitter.com/nori_sgwr/status/557800160328429569?ref_src=twsrc%5Etfw">January
# https://twitter.com/nanayan_sj/status/529998464961105920?ref_src=twsrc%5Etfw">November
# https://twitter.com/maroemon2/status/839342633281466369?ref_src=twsrc%5Etfw">March
# https://twitter.com/fx_Binary_2000/status/950990489171324928?ref_src=twsrc%5Etfw">January
# https://twitter.com/tokiha_sackun/status/1199688159522484225?ref_src=twsrc%5Etfw">November
# https://twitter.com/Archer05213/status/1147180102297387008?ref_src=twsrc%5Etfw">July
# https://twitter.com/aki_714/status/1079530821470416896?ref_src=twsrc%5Etfw">December
# https://twitter.com/uldelicious/status/810868186459475969?ref_src=twsrc%5Etfw">December
# https://twitter.com/share?url=https%3A%2F%2Fwww.secinet.info&text=%E3%83%90%E3%82%A4%E3%83%8A%E3%83%AA%E3%83%BC%E3%82%AA%E3%83%97%E3%82%B7%E3%83%A7%E3%83%B3%E6%94%BB%E7%95%A5%E3%83%A9%E3%83%9C%EF%BD%9C%E3%83%90%E3%82%A4%E3%83%8A%E3%83%AA%E3%83%BC%E3%82%AA%E3%83%97%E3%82%B7%E3%83%A7%E3%83%B3%E3%81%A7%E7%A8%BC%E3%81%90%E6%94%BB%E7%95%A5%E6%B3%95%E3%83%BB%E5%BF%85%E5%8B%9D%E6%B3%95%E3%82%92%E7%A0%94%E7%A9%B6%E3%81%97%E3%81%BE%E3%81%99%EF%BC%81"
# No HTML contact form found for secinet.info
# No email addresses found for secinet.info
# No phone numbers found for secinet.info
# No telegram found for secinet.info
# No whatsapp found for secinet.info
#
# ============================================
#
# An error occurred while accessing retar.jp: HTTPSConnectionPool(host='retar.jp', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'retar.jp'. (_ssl.c:1007)")))
#
# ============================================
#
# An error occurred while accessing hg-times.com: HTTPSConnectionPool(host='hg-times.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1007)')))
#
# ============================================
#
# An error occurred while accessing next-hop.net: HTTPSConnectionPool(host='next-hop.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'next-hop.net'. (_ssl.c:1007)")))
#
# ============================================
# No HTML contact form found for fxwinner.net
# No email addresses found for fxwinner.net
# No phone numbers found for fxwinner.net
# No telegram found for fxwinner.net
# No whatsapp found for fxwinner.net
#
# ============================================
# No HTML contact form found for kaigai-toraripi.com
# No email addresses found for kaigai-toraripi.com
# No phone numbers found for kaigai-toraripi.com
# No telegram found for kaigai-toraripi.com
# No whatsapp found for kaigai-toraripi.com
#
# ============================================
#
# An error occurred while accessing evernews.co.kr: HTTPSConnectionPool(host='evernews.co.kr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'evernews.co.kr'. (_ssl.c:1007)")))
#
# ============================================
# Twitter links found for yusuke-fx.com:
# https://twitter.com/yusuke_fx1618?ref_src=twsrc%5Etfw">Tweets
# twitter.com/widgets.js"
# No HTML contact form found for yusuke-fx.com
# No email addresses found for yusuke-fx.com
# No phone numbers found for yusuke-fx.com
# No telegram found for yusuke-fx.com
# No whatsapp found for yusuke-fx.com
#
# ============================================
# Facebook links found for aatenbryo2018.com:
# www.facebook.com/sharer.php?src=bm&u=https%3A%2F%2Faatenbryo2018.com&t=%E5%80%9F%E9%87%91300%E4%B8%87%E3%81%8B%E3%82%89%E5%B9%B4%E5%8F%8E1%E5%84%84%E7%A8%BC%E3%81%8E%E7%B5%8C%E6%B8%88%E7%9A%84%E8%87%AA%E7%94%B1%E3%82%92%E6%89%8B%E3%81%AB%E5%85%A5%E3%82%8C%E3%81%9F%E3%80%8C%E5%85%B7%E4%BD%93%E7%9A%84%E6%88%A6%E7%95%A5%E3%80%8D%E3%82%92%E5%85%AC%E9%96%8B%20-%20Free%20Style%20Life"
# Twitter links found for aatenbryo2018.com:
# twitter.com/widgets.js"></script><script
# twitter.com/intent/tweet?url=https%3A%2F%2Faatenbryo2018.com&text=%E5%80%9F%E9%87%91300%E4%B8%87%E3%81%8B%E3%82%89%E5%B9%B4%E5%8F%8E1%E5%84%84%E7%A8%BC%E3%81%8E%E7%B5%8C%E6%B8%88%E7%9A%84%E8%87%AA%E7%94%B1%E3%82%92%E6%89%8B%E3%81%AB%E5%85%A5%E3%82%8C%E3%81%9F%E3%80%8C%E5%85%B7%E4%BD%93%E7%9A%84%E6%88%A6%E7%95%A5%E3%80%8D%E3%82%92%E5%85%AC%E9%96%8B%20-%20Free%20Style%20Life&tw_p=tweetbutton',
# LinkedIn links found for aatenbryo2018.com:
# linkedin.com/in.js"></script><link
# No HTML contact form found for aatenbryo2018.com
# No email addresses found for aatenbryo2018.com
# No phone numbers found for aatenbryo2018.com
# No telegram found for aatenbryo2018.com
# No whatsapp found for aatenbryo2018.com
#
# ============================================
# Twitter links found for so-yokaze.com:
# https://twitter.com/soyokaze_sarasa"
# No HTML contact form found for so-yokaze.com
# No email addresses found for so-yokaze.com
# Phone numbers for so-yokaze.com:
# ('25', '262', '728', '2930')
# Telegram for so-yokaze.com:
# 2023.08.24
# 2023.08.23
# 2023.08.22
# 2023.08.21
# 2023.08.18
# 2023.08.16
# 2023.08.08
# 2023.08.03
# 2023.08.02
# 2023.08.01
# 45678910
# 2022.06.02
# 2023.08.08
# 2023.08.24
# 2021-2023
# Whatsapp for so-yokaze.com:
# 45678910
# 2021-2023
# Twitter links found for nurse-toushi.com:
# https://twitter.com/MIKAN_POIPOI"
# No HTML contact form found for nurse-toushi.com
# No email addresses found for nurse-toushi.com
# No phone numbers found for nurse-toushi.com
# No telegram found for nurse-toushi.com
# No whatsapp found for nurse-toushi.com
#
# ============================================
#
# An error occurred while accessing economytimes.kr: HTTPSConnectionPool(host='economytimes.kr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'economytimes.kr'. (_ssl.c:1007)")))
#
# ============================================
# No HTML contact form found for kinablo.com
# No email addresses found for kinablo.com
# No phone numbers found for kinablo.com
# Telegram for kinablo.com:
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# 2021.02.27
# No whatsapp found for kinablo.com
#
# ============================================
#
# An error occurred while accessing trend-crypto.com: HTTPSConnectionPool(host='trend-crypto.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c01973dfd00>: Failed to resolve 'trend-crypto.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Twitter links found for m-ken24liberty.com:
# https://twitter.com/noritake_24"><i
# No HTML contact form found for m-ken24liberty.com
# No email addresses found for m-ken24liberty.com
# No phone numbers found for m-ken24liberty.com
# No telegram found for m-ken24liberty.com
# Whatsapp for m-ken24liberty.com:
# 1234567
# No HTML contact form found for ethereumjp.com
# No email addresses found for ethereumjp.com
# No phone numbers found for ethereumjp.com
# No telegram found for ethereumjp.com
# No whatsapp found for ethereumjp.com
#
# ============================================
# No HTML contact form found for 2ch.sc
# No email addresses found for 2ch.sc
# No phone numbers found for 2ch.sc
# No telegram found for 2ch.sc
# No whatsapp found for 2ch.sc
#
# ============================================
# Failed to retrieve website content for jpyblog.com
# Status code: 403
# ============================================
#
# An error occurred while accessing crypto-currency.space: HTTPSConnectionPool(host='crypto-currency.space', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c01972346d0>: Failed to resolve 'crypto-currency.space' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing koreajn.co.kr: HTTPSConnectionPool(host='koreajn.co.kr', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1007)')))
#
# ============================================
#
# An error occurred while accessing ol-happy-money.com: HTTPSConnectionPool(host='ol-happy-money.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0197234250>: Failed to resolve 'ol-happy-money.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Twitter links found for kabudamono.com:
# https://twitter.com/oku_pass">Twitter</a></li>
# https://twitter.com/oku_pass">Twitter</a></li>
# https://twitter.com/oku_pass">Twitter</a></li>
# https://twitter.com/oku_pass">Twitter</a></li>
# No HTML contact form found for kabudamono.com
# No email addresses found for kabudamono.com
# No phone numbers found for kabudamono.com
# No telegram found for kabudamono.com
# Whatsapp for kabudamono.com:
# 1890597
# 1890597
# 1890597
# 1890597
# 1890597
# 1890597
# 1890597
# 1890597
#
# An error occurred while accessing forexup.site: HTTPSConnectionPool(host='forexup.site', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c018be991e0>: Failed to resolve 'forexup.site' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing kinyu-arekore.net: HTTPSConnectionPool(host='kinyu-arekore.net', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c018be99d50>: Failed to resolve 'kinyu-arekore.net' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing paladin-atfx.com: HTTPSConnectionPool(host='paladin-atfx.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0195e5ff10>: Failed to resolve 'paladin-atfx.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Twitter links found for sukeblo.com:
# https://twitter.com/ngskyowl"
# No HTML contact form found for sukeblo.com
# No email addresses found for sukeblo.com
# No phone numbers found for sukeblo.com
# No telegram found for sukeblo.com
# No whatsapp found for sukeblo.com
#
# ============================================
# Instagram links found for technow.com.hk:
# https://www.instagram.com/embed.js";var
# Twitter links found for technow.com.hk:
# twitter.com/widgets.js";var
# No HTML contact form found for technow.com.hk
# No email addresses found for technow.com.hk
# Phone numbers for technow.com.hk:
# ('2', '247', '448', '7139')
# Telegram for technow.com.hk:
# 2008-2023
# Whatsapp for technow.com.hk:
# 2008-2023
# No HTML contact form found for sidebusiness-bank.com
# No email addresses found for sidebusiness-bank.com
# No phone numbers found for sidebusiness-bank.com
# No telegram found for sidebusiness-bank.com
# No whatsapp found for sidebusiness-bank.com
#
# ============================================
#
# An error occurred while accessing hachigami.com: HTTPSConnectionPool(host='hachigami.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c01968b7520>: Failed to resolve 'hachigami.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Facebook links found for trafic-site.ro:
# https://www.facebook.com/sharer.php?s=100&p[title]=Trafic
# https://www.Facebook.com/TraficSiteRo"
# Twitter links found for trafic-site.ro:
# https://Twitter.com/TraficSiteRo"
# No HTML contact form found for trafic-site.ro
# No email addresses found for trafic-site.ro
# No phone numbers found for trafic-site.ro
# Telegram for trafic-site.ro:
# 2008-2023
# Whatsapp for trafic-site.ro:
# 2008-2023
#
# An error occurred while accessing kaigaifx-club.com: HTTPSConnectionPool(host='kaigaifx-club.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0196497a90>: Failed to resolve 'kaigaifx-club.com' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing hanzawa-fx.com: HTTPSConnectionPool(host='hanzawa-fx.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'hanzawa-fx.com'. (_ssl.c:1007)")))
#
# ============================================
# No HTML contact form found for tinytotscouponbook.com
# No email addresses found for tinytotscouponbook.com
# No phone numbers found for tinytotscouponbook.com
# No telegram found for tinytotscouponbook.com
# No whatsapp found for tinytotscouponbook.com
#
# ============================================
#
# An error occurred while accessing otylabomen.net: HTTPSConnectionPool(host='otylabomen.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)')))
#
# ============================================
#
# An error occurred while accessing ehimedayori.com: HTTPSConnectionPool(host='ehimedayori.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c01972eeb00>: Failed to resolve 'ehimedayori.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Twitter links found for banesen.com:
# https://twitter.com/banesen_Lucci"
# twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document,
# https://twitter.com/banesen_Lucci"
# twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document,
# No HTML contact form found for banesen.com
# No email addresses found for banesen.com
# No phone numbers found for banesen.com
# Telegram for banesen.com:
# 2022.07.09
# 2022.07.11
# 2022.01.18
# 2021.08.07
# 2021.06.30
# 2021.07.01
# 2021.06.28
# 2021.06.23
# 2021.06.30
# 2021.06.14
# 2021.06.30
# 2021.06.14
# 2021.06.26
# 2020.06.24
# 2021.06.26
# 2020.03.07
# 2021.06.26
# 08.082021
# 08.122021
# 03.092021
# 11.132021
# 12.032021
# 07.092022
# 2022.01.18
# 2021.08.07
# 06.302021
# 2021.06.28
# 2021.09.30
# 2021.07.24
# 2021.07.23
# 2016-2023
# Whatsapp for banesen.com:
# 11.132021
# 12.032021
# 2016-2023
# No HTML contact form found for skyprs.jp
# No email addresses found for skyprs.jp
# No phone numbers found for skyprs.jp
# Telegram for skyprs.jp:
# 2023.05.24
# 2023.05.24
# 2023.05.24
# 2023.05.24
# 2023.05.24
# 2023.05.24
# No whatsapp found for skyprs.jp
#
# ============================================
# Twitter links found for vivinishi.com:
# https://twitter.com/vivi_nishi"><i
# https://twitter.com/vivi_nishi"><i
# No HTML contact form found for vivinishi.com
# No email addresses found for vivinishi.com
# No phone numbers found for vivinishi.com
# No telegram found for vivinishi.com
# No whatsapp found for vivinishi.com
#
# ============================================
# No HTML contact form found for goo.ne.jp
# No email addresses found for goo.ne.jp
# No phone numbers found for goo.ne.jp
# No telegram found for goo.ne.jp
# No whatsapp found for goo.ne.jp
#
# ============================================
# No HTML contact form found for matomeyowww.com
# No email addresses found for matomeyowww.com
# No phone numbers found for matomeyowww.com
# No telegram found for matomeyowww.com
# No whatsapp found for matomeyowww.com
#
# ============================================
# No HTML contact form found for ksdaily.co.kr
# Email addresses for ksdaily.co.kr:
# news002@ksdaily.co.kr
# No phone numbers found for ksdaily.co.kr
# Telegram for ksdaily.co.kr:
# 2023-09-05
# 6956-9902
# 2231-7685
# 2011-04-20
# 1990-04-30
# Whatsapp for ksdaily.co.kr:
# 6956-9902
# 2231-7685
# No HTML contact form found for highlow-binary.net
# No email addresses found for highlow-binary.net
# No phone numbers found for highlow-binary.net
# Telegram for highlow-binary.net:
# 2021-08-16
# 2021-08-09
# 2021-08-06
# 2021-08-04
# 2021-08-02
# 2021-07-29
# 2021-07-24
# 2021-07-23
# 2021-07-22
# 2021-07-19
# 2021-07-17
# 2021-07-11
# 2021-08-16
# 2021-08-09
# 2021-08-06
# No whatsapp found for highlow-binary.net
#
# ============================================
# Facebook links found for norian1225.com:
# www.facebook.com/sharer.php?src=bm&u=https%3A%2F%2Fnorian1225.com&t=%E3%81%AE%E3%82%8A%E3%81%82%E3%82%93%E3%81%BF%E3%82%93%E3%81%A4%E3%81%AE%E3%83%96%E3%83%AD%E3%82%B0"
# Twitter links found for norian1225.com:
# https://twitter.com/norian1225"><meta
# twitter.com/intent/tweet?url=https%3A%2F%2Fnorian1225.com&text=%E3%81%AE%E3%82%8A%E3%81%82%E3%82%93%E3%81%BF%E3%82%93%E3%81%A4%E3%81%AE%E3%83%96%E3%83%AD%E3%82%B0&via=https://twitter.com/norian1225&tw_p=tweetbutton',
# https://twitter.com/norian1225?ref_src=twsrc%5Etfw">Tweets
# twitter.com/widgets.js"
# No HTML contact form found for norian1225.com
# No email addresses found for norian1225.com
# No phone numbers found for norian1225.com
# No telegram found for norian1225.com
# No whatsapp found for norian1225.com
#
# ============================================
# YouTube links found for comepass.jp:
# https://www.youtube.com/iframe_api"></script>
# No HTML contact form found for comepass.jp
# No email addresses found for comepass.jp
# No phone numbers found for comepass.jp
# Telegram for comepass.jp:
# 2023.04.02
# 2021.05.15
# 2020.07.26
# 2020.07.19
# 2020.06.20
# 2019.04.29
# 2019.01.28
# No whatsapp found for comepass.jp
#
# ============================================
# Instagram links found for eisukenakanishi.com:
# https://www.instagram.com/_ask35_/"
# Twitter links found for eisukenakanishi.com:
# https://twitter.com/_ask35_"
# YouTube links found for eisukenakanishi.com:
# https://www.youtube.com/@_ask35_"
# No HTML contact form found for eisukenakanishi.com
# No email addresses found for eisukenakanishi.com
# No phone numbers found for eisukenakanishi.com
# No telegram found for eisukenakanishi.com
# No whatsapp found for eisukenakanishi.com
#
# ============================================
# Twitter links found for laughingcat-fx.com:
# https://twitter.com/changeyourmindp?ref_src=twsrc%5Etfw">Tweets
# twitter.com/widgets.js"
# https://twitter.com/changeyourmindp?ref_src=twsrc%5Etfw">Tweets
# No HTML contact form found for laughingcat-fx.com
# No email addresses found for laughingcat-fx.com
# No phone numbers found for laughingcat-fx.com
# Telegram for laughingcat-fx.com:
# 2023.01.03
# 2022.09.19
# 2022.09.19
# 2022.09.19
# 2022.09.19
# 2022.09.19
# 2022.09.19
# 2022.06.24
# No whatsapp found for laughingcat-fx.com
#
# ============================================
# No HTML contact form found for notraxx.ch
# No email addresses found for notraxx.ch
# No phone numbers found for notraxx.ch
# No telegram found for notraxx.ch
# No whatsapp found for notraxx.ch
#
# ============================================
# Facebook links found for corocoro-knowledge.com:
# https://www.facebook.com/examples"></a></li>
# https://www.facebook.com/examples"></a></li>
# Instagram links found for corocoro-knowledge.com:
# http://instagram.com/http://instagram.com/corocoroknowledge"></a></li>
# http://instagram.com/http://instagram.com/corocoroknowledge"></a></li>
# Twitter links found for corocoro-knowledge.com:
# https://twitter.com/corocoroknowledge"
# https://twitter.com/https://twitter.com/corocoroknowledge"></a></li>
# https://twitter.com/https://twitter.com/corocoroknowledge"></a></li>
# http://twitter.com/intent/tweet?text=%E6%B5%B7%E5%A4%96FX%E3%81%AE%E3%82%A4%E3%83%A1%E3%83%BC%E3%82%B8%E3%82%92%E6%89%95%E6%8B%AD%E3%81%97%E6%98%8E%E3%82%8B%E3%81%84%E6%9C%AA%E6%9D%A5%E3%81%B8%E3%81%AE%E6%89%8B%E5%8A%A9%E3%81%91%E3%82%92%E2%94%82%E3%82%B3%E3%83%AD%E3%82%B3%E3%83%AD%E7%9F%A5%E8%AD%98&amp;https%3A%2F%2Fcorocoro-knowledge.com%2F&amp;url=https%3A%2F%2Fcorocoro-knowledge.com%2F"
# LinkedIn links found for corocoro-knowledge.com:
# linkedin.com/in/examples"></a></li>
# linkedin.com/in/examples"></a></li>
# YouTube links found for corocoro-knowledge.com:
# https://www.youtube.com/watch?v=',mute:
# No HTML contact form found for corocoro-knowledge.com
# No email addresses found for corocoro-knowledge.com
# No phone numbers found for corocoro-knowledge.com
# No telegram found for corocoro-knowledge.com
# No whatsapp found for corocoro-knowledge.com
#
# ============================================
# No HTML contact form found for autosystem-labo.com
# No email addresses found for autosystem-labo.com
# No phone numbers found for autosystem-labo.com
# No telegram found for autosystem-labo.com
# No whatsapp found for autosystem-labo.com
#
# ============================================
# Twitter links found for tetolog.com:
# twitter.com/7hubVL5OZf
# twitter.com/h9EdZVCWo6
# twitter.com/KkkeBMLwBC
# No HTML contact form found for tetolog.com
# No email addresses found for tetolog.com
# No phone numbers found for tetolog.com
# No telegram found for tetolog.com
# No whatsapp found for tetolog.com
#
# ============================================
#
# An error occurred while accessing tuulamoilanen.net: HTTPSConnectionPool(host='tuulamoilanen.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'tuulamoilanen.net'. (_ssl.c:1007)")))
#
# ============================================
# No HTML contact form found for sitetr.net
# No email addresses found for sitetr.net
# No phone numbers found for sitetr.net
# No telegram found for sitetr.net
# No whatsapp found for sitetr.net
#
# ============================================
# No HTML contact form found for ea-fx.click
# No email addresses found for ea-fx.click
# No phone numbers found for ea-fx.click
# Telegram for ea-fx.click:
# 2020.10.17
# 2020.10.10
# 2020.09.26
# 2020.01.29
# 2019.12.18
# No whatsapp found for ea-fx.click
#
# ============================================
# No HTML contact form found for kamimanji.net
# No email addresses found for kamimanji.net
# No phone numbers found for kamimanji.net
# No telegram found for kamimanji.net
# No whatsapp found for kamimanji.net
#
# ============================================
# Twitter links found for 海外fx-guide.com:
# https://twitter.com/haan_fx"></a></li>
# https://twitter.com/haan_fx"></a></li>
# https://twitter.com/haan_fx"></a></li>
# No HTML contact form found for 海外fx-guide.com
# No email addresses found for 海外fx-guide.com
# No phone numbers found for 海外fx-guide.com
# Telegram for 海外fx-guide.com:
# 2022.12.27
# 2022.12.27
# 2022.12.27
# 2022.12.27
# 2022.12.27
# No whatsapp found for 海外fx-guide.com
#
# ============================================
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Facebook links found for ilpn.kr:
# https://www.facebook.com/2358hong"
# Twitter links found for ilpn.kr:
# https://twitter.com/sorijundal"
# YouTube links found for ilpn.kr:
# https://www.youtube.com/embed/RbuGJel8hO8"
# https://www.youtube.com/embed/ONqyqHWMPac"
# No HTML contact form found for ilpn.kr
# No email addresses found for ilpn.kr
# Phone numbers for ilpn.kr:
# ('0', '504', '235', '2358')
# Telegram for ilpn.kr:
# 2023-09-05
# 2013-10-31
# 2013-11-06
# 2013-11-06
# 1800-2358
# (2015-03-04
# (2016-07-28
# Whatsapp for ilpn.kr:
# 1800-2358
# 235-2358
# No HTML contact form found for binary-kouryaku.com
# No email addresses found for binary-kouryaku.com
# No phone numbers found for binary-kouryaku.com
# Telegram for binary-kouryaku.com:
# 2013-2022
# Whatsapp for binary-kouryaku.com:
# 2013-2022
# No HTML contact form found for reiwanavi.tokyo
# No email addresses found for reiwanavi.tokyo
# No phone numbers found for reiwanavi.tokyo
# Telegram for reiwanavi.tokyo:
# 2020.12.07
# 2020.11.28
# 2020.11.25
# 2020.11.14
# 2020.11.12
# 2020.11.07
# 2020.11.06
# 2020.10.05
# 2020.10.02
# 2020.10.02
# No whatsapp found for reiwanavi.tokyo
#
# ============================================
# No HTML contact form found for useless.tk
# No email addresses found for useless.tk
# No phone numbers found for useless.tk
# No telegram found for useless.tk
# No whatsapp found for useless.tk
#
# ============================================
# No HTML contact form found for zaistandard.com
# No email addresses found for zaistandard.com
# No phone numbers found for zaistandard.com
# No telegram found for zaistandard.com
# No whatsapp found for zaistandard.com
#
# ============================================
# No HTML contact form found for crypto-adviser.co
# No email addresses found for crypto-adviser.co
# No phone numbers found for crypto-adviser.co
# Telegram for crypto-adviser.co:
# 2023.08.02
# 2023.07.29
# 2023.07.15
# 2023.07.14
# 2023.07.14
# 2023.07.13
# 2023.06.11
# 2023.06.01
# 2023.06.01
# 2023.05.25
# 2023.03.20
# 2023.08.02
# 2023.03.20
# 2023.03.07
# 2023.03.20
# 2023.03.20
# 2023.03.19
# 2022.11.07
# 2023.07.15
# 2023.03.20
# No whatsapp found for crypto-adviser.co
#
# ============================================
# Facebook links found for technical-fx.com:
# www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftechnical-fx.com%2F&#038;t=FX%E3%81%A7%E5%8B%9D%E3%81%A4%E3%81%9F%E3%82%81%E3%81%AE%E3%83%86%E3%82%AF%E3%83%8B%E3%82%AB%E3%83%AB%E5%88%86%E6%9E%90%E3%82%92%E6%A5%B5%E3%82%81%E3%82%8B%E3%83%96%E3%83%AD%E3%82%B0"
# www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ftechnical-fx.com%2F&#038;t=FX%E3%81%A7%E5%8B%9D%E3%81%A4%E3%81%9F%E3%82%81%E3%81%AE%E3%83%86%E3%82%AF%E3%83%8B%E3%82%AB%E3%83%AB%E5%88%86%E6%9E%90%E3%82%92%E6%A5%B5%E3%82%81%E3%82%8B%E3%83%96%E3%83%AD%E3%82%B0"
# https://www.facebook.com/1450166215288692/"
# https://www.facebook.com/1450166215288692/"
# Twitter links found for technical-fx.com:
# https://twitter.com/intent/tweet?text=FX%E3%81%A7%E5%8B%9D%E3%81%A4%E3%81%9F%E3%82%81%E3%81%AE%E3%83%86%E3%82%AF%E3%83%8B%E3%82%AB%E3%83%AB%E5%88%86%E6%9E%90%E3%82%92%E6%A5%B5%E3%82%81%E3%82%8B%E3%83%96%E3%83%AD%E3%82%B0+%23%E4%B8%AD%E4%BA%8C%E7%97%85FX+%23FX&#038;url=https%3A%2F%2Ftechnical-fx.com%2F&#038;related=tyuunibyouFX"
# https://twitter.com/intent/tweet?text=FX%E3%81%A7%E5%8B%9D%E3%81%A4%E3%81%9F%E3%82%81%E3%81%AE%E3%83%86%E3%82%AF%E3%83%8B%E3%82%AB%E3%83%AB%E5%88%86%E6%9E%90%E3%82%92%E6%A5%B5%E3%82%81%E3%82%8B%E3%83%96%E3%83%AD%E3%82%B0+%23%E4%B8%AD%E4%BA%8C%E7%97%85FX+%23FX&#038;url=https%3A%2F%2Ftechnical-fx.com%2F&#038;related=tyuunibyouFX"
# https://twitter.com/tyuunibyouFX"
# https://twitter.com/tyuunibyouFX"
# No HTML contact form found for technical-fx.com
# No email addresses found for technical-fx.com
# No phone numbers found for technical-fx.com
# Telegram for technical-fx.com:
# 11.162016
# 09.132023
# 09.082023
# 05.222023
# 04.182023
# 04.122023
# 02.102021
# 03.072021
# 02.022021
# 03.102021
# 03.082021
# 03.182021
# 02.262021
# 03.042021
# 03.032021
# 02.232021
# 09.132023
# 09.082023
# 05.222023
# 04.182023
# 04.122023
# 02.102021
# 03.082021
# 03.072021
# 01.202021
# 03.182021
# 01.162021
# 03.042021
# 03.102021
# 02.252021
# 05.222023
# 2016-2023
# Whatsapp for technical-fx.com:
# 11.162016
# 2016-2023
# No HTML contact form found for aircanada0625.com
# No email addresses found for aircanada0625.com
# No phone numbers found for aircanada0625.com
# No telegram found for aircanada0625.com
# No whatsapp found for aircanada0625.com
#
# ============================================
#
# An error occurred while accessing cryptocurrency-summary.biz: HTTPSConnectionPool(host='cryptocurrency-summary.biz', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0196595fc0>: Failed to resolve 'cryptocurrency-summary.biz' ([Errno -2] Name or service not known)"))
#
# ============================================
# No HTML contact form found for howtomt4.com
# No email addresses found for howtomt4.com
# No phone numbers found for howtomt4.com
# Telegram for howtomt4.com:
# 2023.02.08
# 2023.03.07
# 2023.02.14
# 2023.02.22
# 2023.01.31
# 2023.02.17
# 2023.01.21
# 2023.02.20
# 2023.01.12
# 2023.02.19
# 2022.12.29
# 2023.02.19
# 2022.12.15
# 2023.02.17
# 2022.11.29
# 2023.02.19
# 2022.11.15
# 2023.02.19
# 2022.11.03
# 2023.02.17
# 2023.02.08
# 2023.02.14
# 2023.01.31
# No whatsapp found for howtomt4.com
#
# ============================================
# Twitter links found for what-do-you-want.jp:
# https://twitter.com/kanata07111"
# No HTML contact form found for what-do-you-want.jp
# No email addresses found for what-do-you-want.jp
# No phone numbers found for what-do-you-want.jp
# Telegram for what-do-you-want.jp:
# 2023.06.29
# 2023.06.27
# 2023.06.26
# 2023.06.21
# 2023.06.20
# 2023.06.02
# 2023.06.02
# 2023.06.01
# 2023.05.29
# 2023.05.26
# No whatsapp found for what-do-you-want.jp
#
# ============================================
#
# An error occurred while accessing bestcoinsinfo.com: HTTPSConnectionPool(host='bestcoinsinfo.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c01973dc190>: Failed to resolve 'bestcoinsinfo.com' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing jbcka.com: HTTPSConnectionPool(host='jbcka.com', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'jbcka.com'. (_ssl.c:1007)")))
#
# ============================================
#
# An error occurred while accessing i-topics.net: HTTPSConnectionPool(host='i-topics.net', port=443): Max retries exceeded with url: / (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1007)')))
#
# ============================================
# Facebook links found for fx入門無料メルマガ.com:
# www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fxn--fx-dh4apioa4dw635ag17acyvju4f.com%2F&#038;t=MT4%E7%94%A8%E3%82%A4%E3%83%B3%E3%82%B8%E3%82%B1%E3%83%BC%E3%82%BF%E3%83%BC%E9%85%8D%E5%B8%83%E4%B8%AD"
# www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fxn--fx-dh4apioa4dw635ag17acyvju4f.com%2F&#038;t=MT4%E7%94%A8%E3%82%A4%E3%83%B3%E3%82%B8%E3%82%B1%E3%83%BC%E3%82%BF%E3%83%BC%E9%85%8D%E5%B8%83%E4%B8%AD"
# Twitter links found for fx入門無料メルマガ.com:
# https://twitter.com/intent/tweet?text=MT4%E7%94%A8%E3%82%A4%E3%83%B3%E3%82%B8%E3%82%B1%E3%83%BC%E3%82%BF%E3%83%BC%E9%85%8D%E5%B8%83%E4%B8%AD&#038;url=https%3A%2F%2Fxn--fx-dh4apioa4dw635ag17acyvju4f.com%2F"
# https://twitter.com/intent/tweet?text=MT4%E7%94%A8%E3%82%A4%E3%83%B3%E3%82%B8%E3%82%B1%E3%83%BC%E3%82%BF%E3%83%BC%E9%85%8D%E5%B8%83%E4%B8%AD&#038;url=https%3A%2F%2Fxn--fx-dh4apioa4dw635ag17acyvju4f.com%2F"
# No HTML contact form found for fx入門無料メルマガ.com
# No email addresses found for fx入門無料メルマガ.com
# No phone numbers found for fx入門無料メルマガ.com
# Telegram for fx入門無料メルマガ.com:
# 02.192016
# No whatsapp found for fx入門無料メルマガ.com
#
# ============================================
# No HTML contact form found for keyfora.com
# No email addresses found for keyfora.com
# No phone numbers found for keyfora.com
# No telegram found for keyfora.com
# No whatsapp found for keyfora.com
#
# ============================================
# Facebook links found for fx-earn.com:
# www.facebook.com/sharer.php?src=bm&u=https%3A%2F%2Ffx-earn.com&t=SHUBLOG"
# Twitter links found for fx-earn.com:
# twitter.com/intent/tweet?url=https%3A%2F%2Ffx-earn.com&text=SHUBLOG&via=ShuEA11&tw_p=tweetbutton',
# https://twitter.com/shublog_fx"
# https://twitter.com/shublog_fx?ref_src=twsrc%5Etfw"
# twitter.com/widgets.js"
# No HTML contact form found for fx-earn.com
# No email addresses found for fx-earn.com
# No phone numbers found for fx-earn.com
# No telegram found for fx-earn.com
# No whatsapp found for fx-earn.com
#
# ============================================
# Failed to retrieve website content for kaigai-fx-navi.xyz
# Status code: 403
# ============================================
# No HTML contact form found for paypay-howto.xyz
# No email addresses found for paypay-howto.xyz
# No phone numbers found for paypay-howto.xyz
# No telegram found for paypay-howto.xyz
# No whatsapp found for paypay-howto.xyz
#
# ============================================
# Facebook links found for seowave.org:
# https://facebook.com/seowave.org"
# No HTML contact form found for seowave.org
# Email addresses for seowave.org:
# info@example.com
# Phone numbers for seowave.org:
# ('0', '012', '398', '7280')
# No telegram found for seowave.org
# No whatsapp found for seowave.org
#
# ============================================
# Twitter links found for fx初心者.biz:
# https://twitter.com/intent/tweet?screen_name=FxSenior&#038;ref_src=twsrc%5Etfw"
# twitter.com/widgets.js"
# No HTML contact form found for fx初心者.biz
# No email addresses found for fx初心者.biz
# No phone numbers found for fx初心者.biz
# No telegram found for fx初心者.biz
# No whatsapp found for fx初心者.biz
#
# ============================================
# Facebook links found for exnessjapan.com:
# https://www.facebook.com/exness-japan"
# Instagram links found for exnessjapan.com:
# https://www.instagram.com/exness-japan"
# No HTML contact form found for exnessjapan.com
# No email addresses found for exnessjapan.com
# No phone numbers found for exnessjapan.com
# No telegram found for exnessjapan.com
# No whatsapp found for exnessjapan.com
#
# ============================================
# Failed to retrieve website content for onefirst.info
# Status code: 500
# ============================================
# No HTML contact form found for chusotsu-fx.com
# No email addresses found for chusotsu-fx.com
# No phone numbers found for chusotsu-fx.com
# Telegram for chusotsu-fx.com:
# 2023.08.23
# 2023.08.03
# 2023.07.24
# 2023.07.12
# 2023.07.04
# No whatsapp found for chusotsu-fx.com
#
# ============================================
# No HTML contact form found for shinnsui.com
# No email addresses found for shinnsui.com
# No phone numbers found for shinnsui.com
# No telegram found for shinnsui.com
# No whatsapp found for shinnsui.com
#
# ============================================
#
# An error occurred while accessing everglow-inc.com: HTTPSConnectionPool(host='everglow-inc.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0196799660>: Failed to resolve 'everglow-inc.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Facebook links found for ninjafx.site:
# https://www.facebook.com/ninjafx.site"
# https://www.facebook.com/ninjafx.site"
# No HTML contact form found for ninjafx.site
# No email addresses found for ninjafx.site
# No phone numbers found for ninjafx.site
# No telegram found for ninjafx.site
# No whatsapp found for ninjafx.site
#
# ============================================
# Facebook links found for soto-fx.com:
# www.facebook.com/sharer.php?src=bm&u=https%3A%2F%2Fsoto-fx.com&t=%E6%B5%B7%E5%A4%96FX%E3%83%88%E3%83%AC%E3%83%BC%E3%83%89%E3%81%A8%E3%81%8A%E3%81%99%E3%81%99%E3%82%81%E3%81%AE%E6%A5%AD%E8%80%85%E6%AF%94%E8%BC%83%E3%80%90%E3%82%BD%E3%83%88FX%E3%80%91"
# https://www.facebook.com/fxsoto/"
# Twitter links found for soto-fx.com:
# twitter.com/intent/tweet?url=https%3A%2F%2Fsoto-fx.com&text=%E6%B5%B7%E5%A4%96FX%E3%83%88%E3%83%AC%E3%83%BC%E3%83%89%E3%81%A8%E3%81%8A%E3%81%99%E3%81%99%E3%82%81%E3%81%AE%E6%A5%AD%E8%80%85%E6%AF%94%E8%BC%83%E3%80%90%E3%82%BD%E3%83%88FX%E3%80%91&via=soto_fx&tw_p=tweetbutton',
# https://twitter.com/soto_fx"
# No HTML contact form found for soto-fx.com
# No email addresses found for soto-fx.com
# No phone numbers found for soto-fx.com
# No telegram found for soto-fx.com
# No whatsapp found for soto-fx.com
#
# ============================================
# Facebook links found for trgy.co.jp:
# https://www.facebook.com/%E6%A0%AA%E5%BC%8F%E4%BC%9A%E7%A4%BE%E3%83%88%E3%83%AA%E3%83%AD%E3%82%B8%E3%83%BC-174722962637837/"><span>facebook</span></a></li>
# https://www.facebook.com/%E6%A0%AA%E5%BC%8F%E4%BC%9A%E7%A4%BE%E3%83%88%E3%83%AA%E3%83%AD%E3%82%B8%E3%83%BC-174722962637837/"
# Twitter links found for trgy.co.jp:
# https://twitter.com/trilogy372"><span>Twitter</span></a></li>
# https://twitter.com/trilogy372"
# LinkedIn links found for trgy.co.jp:
# https://www.linkedin.com/in/%E9%9A%86%E5%BF%97-%E5%89%8D%E5%B3%B6-50992a69/"
# YouTube links found for trgy.co.jp:
# https://www.youtube.com/channel/UCbNafhSt4iJOyaWylcuwUKg"><span>YouTube</span></a></li>
# https://www.youtube.com/user/trilogy55?pbjreload=10"
# No HTML contact form found for trgy.co.jp
# No email addresses found for trgy.co.jp
# No phone numbers found for trgy.co.jp
# Telegram for trgy.co.jp:
# 6356 4045
# 2023-03-06
# 2023-01-06
# 2022-12-25
# 2022-11-24
# 2022-11-24
# 2022-11-23
# 2022-10-14
# 2022-09-06
# 2008-2023
# Whatsapp for trgy.co.jp:
# 6356 4045
# 2008-2023
# YouTube links found for minami-channel.com:
# https://www.youtube.com/@eafx4068/videos"><span>YouTube</span></a></li>
# https://www.youtube.com/@eafx4068/videos"><span>YouTube</span></a></li>
# https://www.youtube.com/@eafx4068/videos"><span>YouTube</span></a></li>
# No HTML contact form found for minami-channel.com
# No email addresses found for minami-channel.com
# No phone numbers found for minami-channel.com
# No telegram found for minami-channel.com
# No whatsapp found for minami-channel.com
#
# ============================================
# Twitter links found for binary-inception.com:
# https://twitter.com/BinaryInception"
# YouTube links found for binary-inception.com:
# https://www.youtube.com/iframe_api"></script>
# No HTML contact form found for binary-inception.com
# No email addresses found for binary-inception.com
# No phone numbers found for binary-inception.com
# Telegram for binary-inception.com:
# 2019.01.16
# 2019.10.10
# 2019.02.18
# 2019.05.27
# 2019.10.02
# 2019.10.11
# 2019.01.30
# 2019.10.31
# 2019.02.22
# 2019.03.04
# 2019.06.13
# 2019.06.21
# 2019.11.18
# 2018.10.26
# 2018.11.08
# 2018.12.20
# 2019.11.06
# 2019.01.09
# 2019.01.18
# 2019.03.18
# 2019.08.28
# 2019.06.12
# 2019.08.29
# 2019.11.07
# 2019.02.28
# 2019.04.15
# 2019.10.11
# 2019.10.23
# No whatsapp found for binary-inception.com
#
# ============================================
#
# An error occurred while accessing saikou-business.com: HTTPSConnectionPool(host='saikou-business.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0195e271c0>: Failed to resolve 'saikou-business.com' ([Errno -2] Name or service not known)"))
#
# ============================================
# Facebook links found for fx888.info:
# www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Ffx888.info%2F&amp;t=XM%E3%81%A7%E6%B5%B7%E5%A4%96FX%E3%82%92%E5%A7%8B%E3%82%81%E3%82%88%E3%81%86"
# Twitter links found for fx888.info:
# https://twitter.com/intent/tweet?text=XM%E3%81%A7%E6%B5%B7%E5%A4%96FX%E3%82%92%E5%A7%8B%E3%82%81%E3%82%88%E3%81%86&amp;url=https%3A%2F%2Ffx888.info%2F"
# No HTML contact form found for fx888.info
# No email addresses found for fx888.info
# No phone numbers found for fx888.info
# Telegram for fx888.info:
# 10.112018
# Whatsapp for fx888.info:
# 10.112018
#
# An error occurred while accessing logpotchi.com: HTTPSConnectionPool(host='logpotchi.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c018be22530>: Failed to resolve 'logpotchi.com' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing websearch.com: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#
# ============================================
#
# An error occurred while accessing fxsuperhotline.com: HTTPSConnectionPool(host='fxsuperhotline.com', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c0196bed390>: Failed to resolve 'fxsuperhotline.com' ([Errno -2] Name or service not known)"))
#
# ============================================
#
# An error occurred while accessing lcnor.top: HTTPSConnectionPool(host='lcnor.top', port=443): Max retries exceeded with url: / (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7c018be22980>: Failed to resolve 'lcnor.top' ([Errno -2] Name or service not known)"))
#
# ============================================
# No HTML contact form found for prlog.ru
# No email addresses found for prlog.ru
# No phone numbers found for prlog.ru
# No telegram found for prlog.ru
# No whatsapp found for prlog.ru
#
# ============================================
# Twitter links found for yasu272.com:
# https://twitter.com/@HIROs8133"></a></li>
# No HTML contact form found for yasu272.com
# No email addresses found for yasu272.com
# No phone numbers found for yasu272.com
# Telegram for yasu272.com:
# 2021.07.25
# 2021.04.28
# 2020.02.07
# 2020.01.20
# 2019.12.27
# 2019.09.05
# No whatsapp found for yasu272.com
#
# ============================================
# Twitter links found for blog-iroha.com:
# https://twitter.com/iroha_chatgpt"><i
# No HTML contact form found for blog-iroha.com
# No email addresses found for blog-iroha.com
# No phone numbers found for blog-iroha.com
# No telegram found for blog-iroha.com
# No whatsapp found for blog-iroha.com
#
# ============================================
# Twitter links found for bitcoin-walker.com:
# twitter.com/widgets.js"
# No HTML contact form found for bitcoin-walker.com
# No email addresses found for bitcoin-walker.com
# No phone numbers found for bitcoin-walker.com
# Telegram for bitcoin-walker.com:
# 2017.12.30
# 2017.12.30
# No whatsapp found for bitcoin-walker.com
#
# ============================================
